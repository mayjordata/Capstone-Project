# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('bmh')

from time import sleep
from datetime import datetime

import sys
from scipy import sparse
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import pairwise_distances, cosine_similarity

# %% [markdown]
# ## Reading in CSV
# ---

# %%
df = pd.read_csv('../data/Combined_Final_Data/recommender_data.csv')
print(df.shape)
df.head(2)
# Out:
# (799, 36)
#                    team  year  games_played  wins  loss  win_pct  off_pts  \
# 0  New England Patriots  2018            16    11     5    0.688  27.2500
# 1        Miami Dolphins  2018            16     7     9    0.438  19.9375
#
#    def_pts  SRS  SOS  ...  opp_rush_att  opp_rush_yds  opp_rush_TD  opp_plays  \
# 0  20.3125  5.2 -1.8  ...       22.9375      112.6875       0.4375     62.625
# 1  27.0625 -8.8 -1.7  ...       30.3125      145.3125       1.0625     64.000
#
#     opp_yds  opp_yds_play  opp_Fum  opp_Int  opp_TO_Tot  league
# 0  359.1250           5.7   0.6250   1.1250        1.75     NFL
# 1  391.0625           6.1   0.4375   1.3125        1.75     NFL
#
# [2 rows x 36 columns]

# %%
df.tail(2)
# Out:
#               team  year  games_played  wins  loss  win_pct  off_pts  def_pts  \
# 797          Idaho  2014            11     1    10    0.091     25.0     37.3
# 798  Georgia State  2014            12     1    11    0.083     22.7     43.3
#
#        SRS   SOS  ...  opp_rush_att  opp_rush_yds  opp_rush_TD  opp_plays  \
# 797 -19.67 -7.21  ...          43.9         245.9          2.9       66.8
# 798 -20.41 -4.50  ...          48.5         303.4          3.4       75.7
#
#      opp_yds  opp_yds_play  opp_Fum  opp_Int  opp_TO_Tot   league
# 797    462.1           6.9      0.8      0.7         1.5  College
# 798    497.1           6.6      0.4      0.3         0.7  College
#
# [2 rows x 36 columns]

# %%
df.drop(columns=['wins','loss'], inplace=True)

# %% [markdown]
# ## Recommender

# %%
rec_df = df.copy()

# %%
rec_df.shape
# Out:
# (799, 34)

# %%
sys.getsizeof(rec_df)
# Out:
# 309722

# %% [markdown]
# There are 799 rows and 34 columns in the original DataFrame. The memory allocation of this DataFrame is very large at 309,722 bytes. Creating a sparse matrix will reduce this tremendously.

# %%
rec_df.set_index(['team','year','league'], inplace=True)

# %% [markdown]
# Setting my object columns of interest as the index, to allow vector calculations for all of the remaining numerical columns.

# %%
print(rec_df.shape)
rec_df.head(2)
# Out:
# (799, 31)
#                                   games_played  win_pct  off_pts  def_pts  \
# team                 year league
# New England Patriots 2018 NFL               16    0.688  27.2500  20.3125
# Miami Dolphins       2018 NFL               16    0.438  19.9375  27.0625
#
#                                   SRS  SOS  pass_comp  pass_att  comp_pct  \
# team                 year league
# New England Patriots 2018 NFL     5.2 -1.8     23.625   35.8750      65.9
# Miami Dolphins       2018 NFL    -8.8 -1.7     18.250   28.4375      64.2
#
#                                   pass_yds  ...  opp_pass_TD  opp_rush_att  \
# team                 year league            ...
# New England Patriots 2018 NFL        266.1  ...       1.8125       22.9375
# Miami Dolphins       2018 NFL        181.3  ...       1.9375       30.3125
#
#                                   opp_rush_yds  opp_rush_TD  opp_plays  \
# team                 year league
# New England Patriots 2018 NFL         112.6875       0.4375     62.625
# Miami Dolphins       2018 NFL         145.3125       1.0625     64.000
#
#                                    opp_yds  opp_yds_play  opp_Fum  opp_Int  \
# team                 year league
# New England Patriots 2018 NFL     359.1250           5.7   0.6250   1.1250
# Miami Dolphins       2018 NFL     391.0625           6.1   0.4375   1.3125
#
#                                   opp_TO_Tot
# team                 year league
# New England Patriots 2018 NFL           1.75
# Miami Dolphins       2018 NFL           1.75
#
# [2 rows x 31 columns]

# %%
rec_df.dtypes
# Out:
# games_played       int64
# win_pct          float64
# off_pts          float64
# def_pts          float64
# SRS              float64
# SOS              float64
# pass_comp        float64
# pass_att         float64
# comp_pct         float64
# pass_yds         float64
# pass_TD          float64
# rush_att         float64
# rush_yds         float64
# rush_TD          float64
# Fum              float64
# Int              float64
# TO_Tot           float64
# opp_pass_comp    float64
# opp_pass_att     float64
# opp_comp_pct     float64
# opp_pass_yds     float64
# opp_pass_TD      float64
# opp_rush_att     float64
# opp_rush_yds     float64
# opp_rush_TD      float64
# opp_plays        float64
# opp_yds          float64
# opp_yds_play     float64
# opp_Fum          float64
# opp_Int          float64
# opp_TO_Tot       float64
# dtype: object

# %%
sparse_df = sparse.csr_matrix(rec_df)

# %%
sys.getsizeof(sparse_df)
# Out:
# 64

# %%
print(sparse_df[:1])
# Out:
#   (0, 0)	16.0
#   (0, 1)	0.688
#   (0, 2)	27.25
#   (0, 3)	20.3125
#   (0, 4)	5.2
#   (0, 5)	-1.8
#   (0, 6)	23.625
#   (0, 7)	35.875
#   (0, 8)	65.9
#   (0, 9)	266.1
#   (0, 10)	1.8125
#   (0, 11)	29.875
#   (0, 12)	127.3
#   (0, 13)	1.125
#   (0, 14)	0.6875
#   (0, 15)	0.6875
#   (0, 16)	1.375
#   (0, 17)	23.125
#   (0, 18)	37.8125
#   (0, 19)	0.6115702479338843
#   (0, 20)	246.4375
#   (0, 21)	1.8125
#   (0, 22)	22.9375
#   (0, 23)	112.6875
#   (0, 24)	0.4375
#   (0, 25)	62.625
#   (0, 26)	359.125
#   (0, 27)	5.7
#   (0, 28)	0.625
#   (0, 29)	1.125
#   (0, 30)	1.75

# %% [markdown]
# ### Pairwise Distance

# %%
recommender = pairwise_distances(sparse_df, metric = 'cosine')

# %%
recommender[:2]
# Out:
# array([[0.        , 0.0168141 , 0.00872815, ..., 0.0665135 , 0.03244053,
#         0.05790882],
#        [0.0168141 , 0.        , 0.00862556, ..., 0.04374958, 0.02269921,
#         0.03926055]])

# %%
rec_df.index
# Out:
# MultiIndex([('New England Patriots', 2018,     'NFL'),
#             (      'Miami Dolphins', 2018,     'NFL'),
#             (       'Buffalo Bills', 2018,     'NFL'),
#             (       'New York Jets', 2018,     'NFL'),
#             (    'Baltimore Ravens', 2018,     'NFL'),
#             ( 'Pittsburgh Steelers', 2018,     'NFL'),
#             (    'Cleveland Browns', 2018,     'NFL'),
#             (  'Cincinnati Bengals', 2018,     'NFL'),
#             (      'Houston Texans', 2018,     'NFL'),
#             (  'Indianapolis Colts', 2018,     'NFL'),
#             ...
#             (   'Appalachian State', 2014, 'College'),
#             (           'Louisiana', 2014, 'College'),
#             (      'Arkansas State', 2014, 'College'),
#             (         'Texas State', 2014, 'College'),
#             (       'South Alabama', 2014, 'College'),
#             (    'Louisiana-Monroe', 2014, 'College'),
#             (                'Troy', 2014, 'College'),
#             (    'New Mexico State', 2014, 'College'),
#             (               'Idaho', 2014, 'College'),
#             (       'Georgia State', 2014, 'College')],
#            names=['team', 'year', 'league'], length=799)

# %%
recommender_df = pd.DataFrame(recommender, index = rec_df.index, columns = rec_df.index)

# %%
recommender_df
# Out:
# team                              New England Patriots Miami Dolphins  \
# year                                              2018           2018
# league                                             NFL            NFL
# team                 year league
# New England Patriots 2018 NFL                 0.000000       0.016814
# Miami Dolphins       2018 NFL                 0.016814       0.000000
# Buffalo Bills        2018 NFL                 0.008728       0.008626
# New York Jets        2018 NFL                 0.010548       0.001669
# Baltimore Ravens     2018 NFL                 0.005659       0.028029
# ...                                                ...            ...
# Louisiana-Monroe     2014 College             0.026306       0.032701
# Troy                 2014 College             0.047710       0.022770
# New Mexico State     2014 College             0.066514       0.043750
# Idaho                2014 College             0.032441       0.022699
# Georgia State        2014 College             0.057909       0.039261
#
# team                              Buffalo Bills New York Jets  \
# year                                       2018          2018
# league                                      NFL           NFL
# team                 year league
# New England Patriots 2018 NFL          0.008728      0.010548
# Miami Dolphins       2018 NFL          0.008626      0.001669
# Buffalo Bills        2018 NFL          0.000000      0.008636
# New York Jets        2018 NFL          0.008636      0.000000
# Baltimore Ravens     2018 NFL          0.010075      0.021652
# ...                                         ...           ...
# Louisiana-Monroe     2014 College      0.028770      0.031058
# Troy                 2014 College      0.022566      0.032283
# New Mexico State     2014 College      0.038343      0.055252
# Idaho                2014 College      0.019561      0.027405
# Georgia State        2014 College      0.042022      0.046711
#
# team                              Baltimore Ravens Pittsburgh Steelers  \
# year                                          2018                2018
# league                                         NFL                 NFL
# team                 year league
# New England Patriots 2018 NFL             0.005659            0.008603
# Miami Dolphins       2018 NFL             0.028029            0.042957
# Buffalo Bills        2018 NFL             0.010075            0.030693
# New York Jets        2018 NFL             0.021652            0.031510
# Baltimore Ravens     2018 NFL             0.000000            0.019123
# ...                                            ...                 ...
# Louisiana-Monroe     2014 College         0.045837            0.028072
# Troy                 2014 College         0.056254            0.080650
# New Mexico State     2014 College         0.076993            0.095685
# Idaho                2014 College         0.045864            0.051415
# Georgia State        2014 College         0.080107            0.074603
#
# team                              Cleveland Browns Cincinnati Bengals  \
# year                                          2018               2018
# league                                         NFL                NFL
# team                 year league
# New England Patriots 2018 NFL             0.002763           0.012930
# Miami Dolphins       2018 NFL             0.006775           0.001369
# Buffalo Bills        2018 NFL             0.005762           0.010762
# New York Jets        2018 NFL             0.003175           0.000281
# Baltimore Ravens     2018 NFL             0.012237           0.025126
# ...                                            ...                ...
# Louisiana-Monroe     2014 College         0.022128           0.033185
# Troy                 2014 College         0.034678           0.032483
# New Mexico State     2014 College         0.053414           0.056000
# Idaho                2014 College         0.023759           0.028612
# Georgia State        2014 College         0.044189           0.047099
#
# team                              Houston Texans Indianapolis Colts  ...  \
# year                                        2018               2018  ...
# league                                       NFL                NFL  ...
# team                 year league                                     ...
# New England Patriots 2018 NFL           0.002973           0.001609  ...
# Miami Dolphins       2018 NFL           0.017494           0.025120  ...
# Buffalo Bills        2018 NFL           0.012477           0.015893  ...
# New York Jets        2018 NFL           0.010115           0.016629  ...
# Baltimore Ravens     2018 NFL           0.005931           0.009509  ...
# ...                                          ...                ...  ...
# Louisiana-Monroe     2014 College       0.041660           0.025167  ...
# Troy                 2014 College       0.058966           0.059985  ...
# New Mexico State     2014 College       0.085376           0.077861  ...
# Idaho                2014 College       0.046990           0.038941  ...
# Georgia State        2014 College       0.077826           0.063602  ...
#
# team                              Appalachian State Louisiana Arkansas State  \
# year                                           2014      2014           2014
# league                                      College   College        College
# team                 year league
# New England Patriots 2018 NFL              0.037829  0.031240       0.027010
# Miami Dolphins       2018 NFL              0.044025  0.023621       0.027536
# Buffalo Bills        2018 NFL              0.021635  0.015221       0.011603
# New York Jets        2018 NFL              0.045917  0.026251       0.031241
# Baltimore Ravens     2018 NFL              0.022741  0.023365       0.025315
# ...                                             ...       ...            ...
# Louisiana-Monroe     2014 College          0.066362  0.058460       0.028659
# Troy                 2014 College          0.036469  0.026059       0.012003
# New Mexico State     2014 College          0.052828  0.048557       0.018584
# Idaho                2014 College          0.042079  0.034705       0.011080
# Georgia State        2014 College          0.076952  0.065783       0.030751
#
# team                              Texas State South Alabama Louisiana-Monroe  \
# year                                     2014          2014             2014
# league                                College       College          College
# team                 year league
# New England Patriots 2018 NFL        0.032924      0.030543         0.026306
# Miami Dolphins       2018 NFL        0.023884      0.017367         0.032701
# Buffalo Bills        2018 NFL        0.012514      0.010861         0.028770
# New York Jets        2018 NFL        0.029276      0.022797         0.031058
# Baltimore Ravens     2018 NFL        0.028638      0.031751         0.045837
# ...                                       ...           ...              ...
# Louisiana-Monroe     2014 College    0.042601      0.031687         0.000000
# Troy                 2014 College    0.011046      0.005451         0.030723
# New Mexico State     2014 College    0.023201      0.016719         0.033775
# Idaho                2014 College    0.017754      0.010164         0.010588
# Georgia State        2014 College    0.040376      0.027852         0.015045
#
# team                                   Troy New Mexico State     Idaho  \
# year                                   2014             2014      2014
# league                              College          College   College
# team                 year league
# New England Patriots 2018 NFL      0.047710         0.066514  0.032441
# Miami Dolphins       2018 NFL      0.022770         0.043750  0.022699
# Buffalo Bills        2018 NFL      0.022566         0.038343  0.019561
# New York Jets        2018 NFL      0.032283         0.055252  0.027405
# Baltimore Ravens     2018 NFL      0.056254         0.076993  0.045864
# ...                                     ...              ...       ...
# Louisiana-Monroe     2014 College  0.030723         0.033775  0.010588
# Troy                 2014 College  0.000000         0.005368  0.006557
# New Mexico State     2014 College  0.005368         0.000000  0.008966
# Idaho                2014 College  0.006557         0.008966  0.000000
# Georgia State        2014 College  0.013604         0.009103  0.006218
#
# team                              Georgia State
# year                                       2014
# league                                  College
# team                 year league
# New England Patriots 2018 NFL          0.057909
# Miami Dolphins       2018 NFL          0.039261
# Buffalo Bills        2018 NFL          0.042022
# New York Jets        2018 NFL          0.046711
# Baltimore Ravens     2018 NFL          0.080107
# ...                                         ...
# Louisiana-Monroe     2014 College      0.015045
# Troy                 2014 College      0.013604
# New Mexico State     2014 College      0.009103
# Idaho                2014 College      0.006218
# Georgia State        2014 College      0.000000
#
# [799 rows x 799 columns]

# %%
recommender_df.columns
# Out:
# MultiIndex([('New England Patriots', 2018,     'NFL'),
#             (      'Miami Dolphins', 2018,     'NFL'),
#             (       'Buffalo Bills', 2018,     'NFL'),
#             (       'New York Jets', 2018,     'NFL'),
#             (    'Baltimore Ravens', 2018,     'NFL'),
#             ( 'Pittsburgh Steelers', 2018,     'NFL'),
#             (    'Cleveland Browns', 2018,     'NFL'),
#             (  'Cincinnati Bengals', 2018,     'NFL'),
#             (      'Houston Texans', 2018,     'NFL'),
#             (  'Indianapolis Colts', 2018,     'NFL'),
#             ...
#             (   'Appalachian State', 2014, 'College'),
#             (           'Louisiana', 2014, 'College'),
#             (      'Arkansas State', 2014, 'College'),
#             (         'Texas State', 2014, 'College'),
#             (       'South Alabama', 2014, 'College'),
#             (    'Louisiana-Monroe', 2014, 'College'),
#             (                'Troy', 2014, 'College'),
#             (    'New Mexico State', 2014, 'College'),
#             (               'Idaho', 2014, 'College'),
#             (       'Georgia State', 2014, 'College')],
#            names=['team', 'year', 'league'], length=799)

# %%
# movies.loc[movies['title'].str.contains('Gump'), 'title']
df.loc[df['team'].str.contains('State'), 'team']
# Out:
# 162    North Carolina State
# 165           Florida State
# 188              Iowa State
# 192          Oklahoma State
# 193            Kansas State
#                ...
# 789       Appalachian State
# 791          Arkansas State
# 792             Texas State
# 796        New Mexico State
# 798           Georgia State
# Name: team, Length: 135, dtype: object

# %%
recommender_df[('Oklahoma', 2017,     'College')].sort_values()[1:10]
# Out:
# team                  year  league
# Southern Mississippi  2015  College    0.001813
# Alabama               2018  College    0.001820
# Penn State            2017  College    0.001859
# Texas Christian       2015  College    0.002220
# Ohio State            2018  College    0.002251
# Boise State           2015  College    0.002595
# Toledo                2016  College    0.002725
# Fresno State          2018  College    0.002774
# Oklahoma              2015  College    0.002841
# Name: (Oklahoma, 2017, College), dtype: float64

# %% [markdown]
# * This recommender is based off of pairwise distance. Meaning the closer to 0 the more similar two teams are.
# * A drawback noticed is that understandably so, only College teams are compared to other College teams. With NFL this is the same.
#
# NEXT STEPS - A few things I will try next include:
# * Scaling the data and see how the results change.
# * create a recommender using cosine similarity.
# * Comparing 1 NFL team at a time to the entire college DataFrame.
# * Attempt to reduce the amount of columns passed into my recommender.
